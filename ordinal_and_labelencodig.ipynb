# %%
import pandas as pd

# %%
df=pd.read_csv("School_data.csv", index_col = 0)
df.sample(10)
# Out:
#      age  gender review education purchased
# 497   41    Male   Good        PG       Yes
# 864   28  Female   Good    School        No
# 699   51    Male   Good        PG        No
# 670   45    Male   Poor    School        No
# 236   59  Female   Good        UG       Yes
# 250   36    Male   Poor    School       Yes
# 956   50  Female   Good    School        No
# 325   59    Male   Poor        PG        No
# 363   49  Female   Good    School       Yes
# 480   21    Male   Poor        UG        No

# %%
df = df.iloc[:,2:]
df
# Out:
#     review education purchased
# 0     Good    School       Yes
# 1     Good    School       Yes
# 2     Poor        UG       Yes
# 3     Good    School        No
# 4     Poor    School       Yes
# ..     ...       ...       ...
# 995   Good        PG        No
# 996   Poor        PG       Yes
# 997   Good    School       Yes
# 998   Poor        PG       Yes
# 999   Good    School        No
#
# [1000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df.iloc[:,0:2], df.iloc[:,-1], test_size = 0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories = [['Poor','Good'],['School', 'UG' , 'PG']])
oe.fit(x_train)
x_train=oe.transform(x_train)
x_test=oe.transform(x_test)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder
le.fit(y_train)
LabelEncoder.transform(y_train)
LabelEncoder.tranform(y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 from sklearn.preprocessing import LabelEncoder
# ----> 2 LabelEncoder.fit(y_train)
#       3 LabelEncoder.transform(y_train)
#       4 LabelEncoder.tranform(y_test)
#
# TypeError: LabelEncoder.fit() missing 1 required positional argument: 'y'
